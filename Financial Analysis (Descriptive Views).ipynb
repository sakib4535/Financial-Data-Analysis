# %%
import pandas as pd
import numpy as np
import yfinance as yf

# %%
start = "2014-01-01"
end = "2022-01-01"

# %%
symbol = "BA"

# %%
df = yf.download(symbol, start, end)
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2013-12-31  136.160004  137.050003  135.740005  136.490005  116.654099
# 2014-01-02  136.009995  137.250000  135.509995  136.669998  116.807953
# 2014-01-03  137.059998  138.500000  137.050003  137.619995  117.619843
# 2014-01-06  139.399994  139.759995  137.800003  138.410004  118.295090
# 2014-01-07  138.580002  141.100006  138.500000  140.509995  120.089905
# ...                ...         ...         ...         ...         ...
# 2021-12-27  201.990005  203.429993  199.100006  203.169998  203.169998
# 2021-12-28  202.229996  208.940002  201.649994  206.130005  206.130005
# 2021-12-29  205.360001  205.410004  202.600006  203.660004  203.660004
# 2021-12-30  203.000000  206.000000  202.600006  202.710007  202.710007
# 2021-12-31  202.199997  203.690002  200.029999  201.320007  201.320007
#
#              Volume
# Date
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2016 entries, 2013-12-31 to 2021-12-31
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2016 non-null   float64
#  1   High       2016 non-null   float64
#  2   Low        2016 non-null   float64
#  3   Close      2016 non-null   float64
#  4   Adj Close  2016 non-null   float64
#  5   Volume     2016 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 110.2 KB

# %%
symbol_2 = ["BTC-USD", "MSFT", "GC=F", "^DJI", "EURUSD=X", "BA"]

# %%
df2 = yf.download(symbol_2, start, end)
df2
# Out:
# [*********************100%***********************]  6 of 6 completed
#              Adj Close                                                   \
#                     BA       BTC-USD  EURUSD=X         GC=F        MSFT
# Date
# 2013-12-31  116.654099           NaN  1.381006  1201.900024   31.937872
# 2014-01-01         NaN           NaN  1.374495          NaN         NaN
# 2014-01-02  116.807953           NaN  1.376671  1225.000000   31.724428
# 2014-01-03  117.619843           NaN  1.366662  1238.400024   31.511009
# 2014-01-06  118.295090           NaN  1.359601  1237.800049   30.845095
# ...                ...           ...       ...          ...         ...
# 2021-12-27  203.169998  50640.417969  1.132426  1808.099976  340.949280
# 2021-12-28  206.130005  47588.855469  1.133003  1810.199951  339.754517
# 2021-12-29  203.660004  46444.710938  1.131478  1805.099976  340.451477
# 2021-12-30  202.710007  47178.125000  1.136015  1812.699951  337.832977
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2849 entries, 2013-12-31 to 2021-12-31
# Data columns (total 36 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   (Adj Close, BA)        2016 non-null   float64
#  1   (Adj Close, BTC-USD)   2663 non-null   float64
#  2   (Adj Close, EURUSD=X)  2086 non-null   float64
#  3   (Adj Close, GC=F)      2014 non-null   float64
#  4   (Adj Close, MSFT)      2016 non-null   float64
#  5   (Adj Close, ^DJI)      2016 non-null   float64
#  6   (Close, BA)            2016 non-null   float64
#  7   (Close, BTC-USD)       2663 non-null   float64
#  8   (Close, EURUSD=X)      2086 non-null   float64
#  9   (Close, GC=F)          2014 non-null   float64
#  10  (Close, MSFT)          2016 non-null   float64
#  11  (Close, ^DJI)          2016 non-null   float64
#  12  (High, BA)             2016 non-null   float64
#  13  (High, BTC-USD)        2663 non-null   float64
# ...

# %%
df2.to_csv("assests_list.csv")

# %%
#Inspection and Investigation

# %%
import pandas as pd 
import matplotlib.pyplot as plt
pd.options.display.float_format = "{:.4f}".format
plt.style.use("seaborn")

# %%
pd.read_csv("assests_list.csv")
# Out:
#       Unnamed: 0           Adj Close     Adj Close.1         Adj Close.2  \
# 0            NaN                  BA         BTC-USD            EURUSD=X
# 1           Date                 NaN             NaN                 NaN
# 2     2013-12-31  116.65409851074219             NaN  1.3810056447982788
# 3     2014-01-01                 NaN             NaN  1.3744947910308838
# 4     2014-01-02  116.80795288085938             NaN  1.3766709566116333
# ...          ...                 ...             ...                 ...
# 2846  2021-12-27   203.1699981689453  50640.41796875  1.1324259042739868
# 2847  2021-12-28   206.1300048828125  47588.85546875  1.1330032348632812
# 2848  2021-12-29  203.66000366210938   46444.7109375     1.1314777135849
# 2849  2021-12-30   202.7100067138672       47178.125  1.1360150575637817
# 2850  2021-12-31  201.32000732421875   46306.4453125   1.132502794265747
#
#              Adj Close.3         Adj Close.4      Adj Close.5  \
# ...

# %%
df =pd.read_csv("assests_list.csv", header=[0,1], index_col=0, parse_dates=[0])
df
# Out:
#            Adj Close                                                    \
#                   BA    BTC-USD EURUSD=X      GC=F     MSFT       ^DJI
# Date
# 2013-12-31  116.6541        NaN   1.3810 1201.9000  31.9379 16576.6602
# 2014-01-01       NaN        NaN   1.3745       NaN      NaN        NaN
# 2014-01-02  116.8080        NaN   1.3767 1225.0000  31.7244 16441.3496
# 2014-01-03  117.6198        NaN   1.3667 1238.4000  31.5110 16469.9902
# 2014-01-06  118.2951        NaN   1.3596 1237.8000  30.8451 16425.0996
# ...              ...        ...      ...       ...      ...        ...
# 2021-12-27  203.1700 50640.4180   1.1324 1808.1000 340.9493 36302.3789
# 2021-12-28  206.1300 47588.8555   1.1330 1810.2000 339.7545 36398.2109
# 2021-12-29  203.6600 46444.7109   1.1315 1805.1000 340.4515 36488.6289
# 2021-12-30  202.7100 47178.1250   1.1360 1812.7000 337.8330 36398.0781
# 2021-12-31  201.3200 46306.4453   1.1325 1827.5000 334.8461 36338.3008
#
# ...

# %%
df.Open
# Out:
#                  BA    BTC-USD  EURUSD=X      GC=F     MSFT       ^DJI
# Date
# 2013-12-31 136.1600        NaN    1.3808 1196.4000  37.4000 16512.3809
# 2014-01-01      NaN        NaN    1.3745       NaN      NaN        NaN
# 2014-01-02 136.0100        NaN    1.3766 1204.3000  37.3500 16572.1699
# 2014-01-03 137.0600        NaN    1.3666 1221.7000  37.2000 16456.8906
# 2014-01-06 139.4000        NaN    1.3596 1232.8000  36.8500 16474.0391
# ...             ...        ...       ...       ...      ...        ...
# 2021-12-27 201.9900 50802.6094    1.1324 1810.0000 335.4600 35954.4805
# 2021-12-28 202.2300 50679.8594    1.1330 1812.0000 343.1500 36302.9883
# 2021-12-29 205.3600 47623.8711    1.1313 1803.2000 341.3000 36421.1406
# 2021-12-30 203.0000 46490.6055    1.1360 1801.7000 341.9100 36522.4805
# 2021-12-31 202.2000 47169.3711    1.1323 1825.1000 338.5100 36385.8516
#
# [2849 rows x 6 columns]

# %%
df.Open["BTC-USD"]
# Out:
# Date
# 2013-12-31          NaN
# 2014-01-01          NaN
# 2014-01-02          NaN
# 2014-01-03          NaN
# 2014-01-06          NaN
#                 ...
# 2021-12-27   50802.6094
# 2021-12-28   50679.8594
# 2021-12-29   47623.8711
# 2021-12-30   46490.6055
# 2021-12-31   47169.3711
# Name: BTC-USD, Length: 2849, dtype: float64

# %%
df.Close
# Out:
#                  BA    BTC-USD  EURUSD=X      GC=F     MSFT       ^DJI
# Date
# 2013-12-31 136.4900        NaN    1.3810 1201.9000  37.4100 16576.6602
# 2014-01-01      NaN        NaN    1.3745       NaN      NaN        NaN
# 2014-01-02 136.6700        NaN    1.3767 1225.0000  37.1600 16441.3496
# 2014-01-03 137.6200        NaN    1.3667 1238.4000  36.9100 16469.9902
# 2014-01-06 138.4100        NaN    1.3596 1237.8000  36.1300 16425.0996
# ...             ...        ...       ...       ...      ...        ...
# 2021-12-27 203.1700 50640.4180    1.1324 1808.1000 342.4500 36302.3789
# 2021-12-28 206.1300 47588.8555    1.1330 1810.2000 341.2500 36398.2109
# 2021-12-29 203.6600 46444.7109    1.1315 1805.1000 341.9500 36488.6289
# 2021-12-30 202.7100 47178.1250    1.1360 1812.7000 339.3200 36398.0781
# 2021-12-31 201.3200 46306.4453    1.1325 1827.5000 336.3200 36338.3008
#
# [2849 rows x 6 columns]

# %%
df.Close.BA
# Out:
# Date
# 2013-12-31   136.4900
# 2014-01-01        NaN
# 2014-01-02   136.6700
# 2014-01-03   137.6200
# 2014-01-06   138.4100
#                ...
# 2021-12-27   203.1700
# 2021-12-28   206.1300
# 2021-12-29   203.6600
# 2021-12-30   202.7100
# 2021-12-31   201.3200
# Name: BA, Length: 2849, dtype: float64

# %%
df.loc[:, ("Close", "BTC-USD")]
# Out:
# Date
# 2013-12-31          NaN
# 2014-01-01          NaN
# 2014-01-02          NaN
# 2014-01-03          NaN
# 2014-01-06          NaN
#                 ...
# 2021-12-27   50640.4180
# 2021-12-28   47588.8555
# 2021-12-29   46444.7109
# 2021-12-30   47178.1250
# 2021-12-31   46306.4453
# Name: (Close, BTC-USD), Length: 2849, dtype: float64

# %%
df.loc["2020-01-01"]
# Out:
# Adj Close  BA                      NaN
#            BTC-USD           7200.1743
#            EURUSD=X             1.1221
#            GC=F                    NaN
#            MSFT                    NaN
#            ^DJI                    NaN
# Close      BA                      NaN
#            BTC-USD           7200.1743
#            EURUSD=X             1.1221
#            GC=F                    NaN
#            MSFT                    NaN
#            ^DJI                    NaN
# High       BA                      NaN
#            BTC-USD           7254.3306
#            EURUSD=X             1.1228
#            GC=F                    NaN
#            MSFT                    NaN
#            ^DJI                    NaN
# Low        BA                      NaN
#            BTC-USD           7174.9443
#            EURUSD=X             1.1159
#            GC=F                    NaN
#            MSFT                    NaN
#            ^DJI                    NaN
# ...

# %%
# One month for one column
df.loc["2018-05", ("Close", "BTC-USD")]
# Out:
# Date
# 2018-05-01   9119.0098
# 2018-05-02   9235.9199
# 2018-05-03   9743.8604
# 2018-05-04   9700.7598
# 2018-05-05   9858.1504
# 2018-05-06   9654.7998
# 2018-05-07   9373.0098
# 2018-05-08   9234.8203
# 2018-05-09   9325.1797
# 2018-05-10   9043.9404
# 2018-05-11   8441.4902
# 2018-05-12   8504.8896
# 2018-05-13   8723.9404
# 2018-05-14   8716.7900
# 2018-05-15   8510.3799
# 2018-05-16   8368.8301
# 2018-05-17   8094.3198
# 2018-05-18   8250.9697
# 2018-05-19   8247.1797
# 2018-05-20   8513.2500
# 2018-05-21   8418.9902
# 2018-05-22   8041.7798
# 2018-05-23   7557.8198
# 2018-05-24   7587.3398
# 2018-05-25   7480.1401
# 2018-05-26   7355.8799
# 2018-05-27   7368.2202
# 2018-05-28   7135.9902
# 2018-05-29   7472.5898
# 2018-05-30   7406.5200
# 2018-05-31   7494.1699
# Name: (Close, BTC-USD), dtype: float64

# %%
df2 = df.swaplevel(axis="columns").sort_index(axis="columns") #swap outer and inner index
df2
# Out:
#                   BA                                                   \
#            Adj Close    Close     High      Low     Open       Volume
# Date
# 2013-12-31  116.6541 136.4900 137.0500 135.7400 136.1600 2096000.0000
# 2014-01-01       NaN      NaN      NaN      NaN      NaN          NaN
# 2014-01-02  116.8080 136.6700 137.2500 135.5100 136.0100 3366700.0000
# 2014-01-03  117.6198 137.6200 138.5000 137.0500 137.0600 3177400.0000
# 2014-01-06  118.2951 138.4100 139.7600 137.8000 139.4000 4196500.0000
# ...              ...      ...      ...      ...      ...          ...
# 2021-12-27  203.1700 203.1700 203.4300 199.1000 201.9900 7818900.0000
# 2021-12-28  206.1300 206.1300 208.9400 201.6500 202.2300 8879700.0000
# 2021-12-29  203.6600 203.6600 205.4100 202.6000 205.3600 6119000.0000
# 2021-12-30  202.7100 202.7100 206.0000 202.6000 203.0000 7012600.0000
# 2021-12-31  201.3200 201.3200 203.6900 200.0300 202.2000 8053000.0000
#
# ...

# %%
df2["EURUSD=X"]
# Out:
#             Adj Close  Close   High    Low   Open  Volume
# Date
# 2013-12-31     1.3810 1.3810 1.3813 1.3761 1.3808  0.0000
# 2014-01-01     1.3745 1.3745 1.3779 1.3744 1.3745  0.0000
# 2014-01-02     1.3767 1.3767 1.3775 1.3633 1.3766  0.0000
# 2014-01-03     1.3667 1.3667 1.3673 1.3602 1.3666  0.0000
# 2014-01-06     1.3596 1.3596 1.3646 1.3573 1.3596  0.0000
# ...               ...    ...    ...    ...    ...     ...
# 2021-12-27     1.1324 1.1324 1.1335 1.1304 1.1324  0.0000
# 2021-12-28     1.1330 1.1330 1.1336 1.1290 1.1330  0.0000
# 2021-12-29     1.1315 1.1315 1.1370 1.1275 1.1313  0.0000
# 2021-12-30     1.1360 1.1360 1.1360 1.1301 1.1360  0.0000
# 2021-12-31     1.1325 1.1325 1.1379 1.1305 1.1323  0.0000
#
# [2849 rows x 6 columns]

# %%
close = df.Close.copy()
close
# Out:
#                  BA    BTC-USD  EURUSD=X      GC=F     MSFT       ^DJI
# Date
# 2013-12-31 136.4900        NaN    1.3810 1201.9000  37.4100 16576.6602
# 2014-01-01      NaN        NaN    1.3745       NaN      NaN        NaN
# 2014-01-02 136.6700        NaN    1.3767 1225.0000  37.1600 16441.3496
# 2014-01-03 137.6200        NaN    1.3667 1238.4000  36.9100 16469.9902
# 2014-01-06 138.4100        NaN    1.3596 1237.8000  36.1300 16425.0996
# ...             ...        ...       ...       ...      ...        ...
# 2021-12-27 203.1700 50640.4180    1.1324 1808.1000 342.4500 36302.3789
# 2021-12-28 206.1300 47588.8555    1.1330 1810.2000 341.2500 36398.2109
# 2021-12-29 203.6600 46444.7109    1.1315 1805.1000 341.9500 36488.6289
# 2021-12-30 202.7100 47178.1250    1.1360 1812.7000 339.3200 36398.0781
# 2021-12-31 201.3200 46306.4453    1.1325 1827.5000 336.3200 36338.3008
#
# [2849 rows x 6 columns]

# %%
df.loc["2018-01-01"] #One day single row
# Out:
# Adj Close  BA                      NaN
#            BTC-USD          13657.2002
#            EURUSD=X             1.2005
#            GC=F                    NaN
#            MSFT                    NaN
#            ^DJI                    NaN
# Close      BA                      NaN
#            BTC-USD          13657.2002
#            EURUSD=X             1.2005
#            GC=F                    NaN
#            MSFT                    NaN
#            ^DJI                    NaN
# High       BA                      NaN
#            BTC-USD          14112.2002
#            EURUSD=X             1.2015
#            GC=F                    NaN
#            MSFT                    NaN
#            ^DJI                    NaN
# Low        BA                      NaN
#            BTC-USD          13154.7002
#            EURUSD=X             1.1999
#            GC=F                    NaN
#            MSFT                    NaN
#            ^DJI                    NaN
# ...

# %%
describe = df.Close.describe()
describe1 = df.Volume.describe()
describe2 = df.Open.describe()

describe, describe1, describe2
# Out:
# (             BA    BTC-USD  EURUSD=X      GC=F      MSFT       ^DJI
#  count 2016.0000  2663.0000 2086.0000 2014.0000 2016.0000  2016.0000
#  mean   218.8366 10760.2313    1.1629 1396.0305  114.6277 23301.0382
#  std     90.9249 15716.1571    0.0783  245.2222   79.1351  5722.2429
#  min     95.0100   178.1030    1.0390 1050.8000   34.9800 15372.7998
#  25%    136.0725   596.2070    1.1114 1226.4250   51.2800 17850.6445
#  50%    184.9200  6173.2300    1.1379 1293.3000   86.1500 23450.0596
#  75%    320.9550 10217.7397    1.1901 1530.7250  153.6800 26686.4819
#  max    440.6200 67566.8281    1.3931 2051.5000  343.1100 36488.6289,
#                    BA           BTC-USD  EURUSD=X        GC=F           MSFT  \
#  count      2016.0000         2663.0000 2086.0000   2014.0000      2016.0000
#  mean    8302478.2242  14470253903.5479    0.0000   5629.8729  30324637.5992
#  std    10955566.8654  20071043365.0834    0.0000  30959.6012  14501116.1092
# ...

# %%
close["BTC-USD"].dropna().plot(figsize=(15,10), fontsize=15)
plt.xlabel("Timeline(Year)", fontsize=15)
plt.ylabel("Closing Price", fontsize=15)
plt.legend(fontsize=15)
plt.show()

# %%
df.Close.dropna().plot(figsize=(17,10), fontsize=15)
plt.legend()
plt.show()

# %% [markdown]
# # Financial Normalizing For Time-Series to Base Value(100)

# %%
df.Close.iloc[0,0]
# Out:
# 136.49000549316406

# %%
df.Close[["BA", "BTC-USD"]].div(df.Close.iloc[0,0])
# Out:
#                BA  BTC-USD
# Date
# 2013-12-31 1.0000      NaN
# 2014-01-01    NaN      NaN
# 2014-01-02 1.0013      NaN
# 2014-01-03 1.0083      NaN
# 2014-01-06 1.0141      NaN
# ...           ...      ...
# 2021-12-27 1.4885 371.0192
# 2021-12-28 1.5102 348.6618
# 2021-12-29 1.4921 340.2792
# 2021-12-30 1.4852 345.6526
# 2021-12-31 1.4750 339.2662
#
# [2849 rows x 2 columns]

# %%
df.Close.iloc[0] #First price of all tickers
# Out:
# BA           136.4900
# BTC-USD           NaN
# EURUSD=X       1.3810
# GC=F        1201.9000
# MSFT          37.4100
# ^DJI       16576.6602
# Name: 2013-12-31 00:00:00, dtype: float64

# %%
norm = df.Close.div(df.Close.iloc[0]).mul(100)
norm
# Out:
#                  BA  BTC-USD  EURUSD=X     GC=F     MSFT     ^DJI
# Date
# 2013-12-31 100.0000      NaN  100.0000 100.0000 100.0000 100.0000
# 2014-01-01      NaN      NaN   99.5285      NaN      NaN      NaN
# 2014-01-02 100.1319      NaN   99.6861 101.9220  99.3317  99.1837
# 2014-01-03 100.8279      NaN   98.9613 103.0369  98.6635  99.3565
# 2014-01-06 101.4067      NaN   98.4501 102.9869  96.5785  99.0857
# ...             ...      ...       ...      ...      ...      ...
# 2021-12-27 148.8534      NaN   82.0001 150.4368 915.3970 218.9969
# 2021-12-28 151.0221      NaN   82.0419 150.6115 912.1893 219.5751
# 2021-12-29 149.2124      NaN   81.9314 150.1872 914.0604 220.1205
# 2021-12-30 148.5164      NaN   82.2600 150.8195 907.0302 219.5743
# 2021-12-31 147.4980      NaN   82.0057 152.0509 899.0110 219.2136
#
# [2849 rows x 6 columns]

# %%
norm.plot(figsize=(15,10), fontsize=13, logy=True) #BTC-USD not granted(NaN)
plt.legend(fontsize=13)
plt.show()

# %%
df.Close.to_csv("close.csv")

# %% [markdown]
# # Price Changes

# %%
close = pd.read_csv("close.csv", index_col="Date", parse_dates=["Date"])
close
# Out:
#                  BA    BTC-USD  EURUSD=X      GC=F     MSFT       ^DJI
# Date
# 2013-12-31 136.4900        NaN    1.3810 1201.9000  37.4100 16576.6602
# 2014-01-01      NaN        NaN    1.3745       NaN      NaN        NaN
# 2014-01-02 136.6700        NaN    1.3767 1225.0000  37.1600 16441.3496
# 2014-01-03 137.6200        NaN    1.3667 1238.4000  36.9100 16469.9902
# 2014-01-06 138.4100        NaN    1.3596 1237.8000  36.1300 16425.0996
# ...             ...        ...       ...       ...      ...        ...
# 2021-12-27 203.1700 50640.4180    1.1324 1808.1000 342.4500 36302.3789
# 2021-12-28 206.1300 47588.8555    1.1330 1810.2000 341.2500 36398.2109
# 2021-12-29 203.6600 46444.7109    1.1315 1805.1000 341.9500 36488.6289
# 2021-12-30 202.7100 47178.1250    1.1360 1812.7000 339.3200 36398.0781
# 2021-12-31 201.3200 46306.4453    1.1325 1827.5000 336.3200 36338.3008
#
# [2849 rows x 6 columns]

# %%
close["MSFT"].shift(periods=1).to_frame()
# Out:
#                MSFT
# Date
# 2013-12-31      NaN
# 2014-01-01  37.4100
# 2014-01-02      NaN
# 2014-01-03  37.1600
# 2014-01-06  36.9100
# ...             ...
# 2021-12-27      NaN
# 2021-12-28 342.4500
# 2021-12-29 341.2500
# 2021-12-30 341.9500
# 2021-12-31 339.3200
#
# [2849 rows x 1 columns]

# %%
msft = close.MSFT.dropna().to_frame().copy()

# %%
msft
# Out:
#                MSFT
# Date
# 2013-12-31  37.4100
# 2014-01-02  37.1600
# 2014-01-03  36.9100
# 2014-01-06  36.1300
# 2014-01-07  36.4100
# ...             ...
# 2021-12-27 342.4500
# 2021-12-28 341.2500
# 2021-12-29 341.9500
# 2021-12-30 339.3200
# 2021-12-31 336.3200
#
# [2016 rows x 1 columns]

# %%
msft.rename(columns={"MSFT":"Price"}, inplace=True)

# %%
msft
# Out:
#               Price
# Date
# 2013-12-31  37.4100
# 2014-01-02  37.1600
# 2014-01-03  36.9100
# 2014-01-06  36.1300
# 2014-01-07  36.4100
# ...             ...
# 2021-12-27 342.4500
# 2021-12-28 341.2500
# 2021-12-29 341.9500
# 2021-12-30 339.3200
# 2021-12-31 336.3200
#
# [2016 rows x 1 columns]

# %%
msft.shift(periods=1)
# Out:
#               Price
# Date
# 2013-12-31      NaN
# 2014-01-02  37.4100
# 2014-01-03  37.1600
# 2014-01-06  36.9100
# 2014-01-07  36.1300
# ...             ...
# 2021-12-27 334.6900
# 2021-12-28 342.4500
# 2021-12-29 341.2500
# 2021-12-30 341.9500
# 2021-12-31 339.3200
#
# [2016 rows x 1 columns]

# %%
msft["price_lag1"] = msft.shift(periods=1)
msft
# Out:
#               Price  price_lag1
# Date
# 2013-12-31  37.4100         NaN
# 2014-01-02  37.1600     37.4100
# 2014-01-03  36.9100     37.1600
# 2014-01-06  36.1300     36.9100
# 2014-01-07  36.4100     36.1300
# ...             ...         ...
# 2021-12-27 342.4500    334.6900
# 2021-12-28 341.2500    342.4500
# 2021-12-29 341.9500    341.2500
# 2021-12-30 339.3200    341.9500
# 2021-12-31 336.3200    339.3200
#
# [2016 rows x 2 columns]

# %% [markdown]
# # Absolute Price Changes (Diff)

# %%
# msft["price_diff"] = msft.Price.sub["price_lag1"] #ALt

# %%
msft["price_diff"] = msft.Price.diff(periods=1)
msft
# Out:
#               Price  price_lag1  price_diff
# Date
# 2013-12-31  37.4100         NaN         NaN
# 2014-01-02  37.1600     37.4100     -0.2500
# 2014-01-03  36.9100     37.1600     -0.2500
# 2014-01-06  36.1300     36.9100     -0.7800
# 2014-01-07  36.4100     36.1300      0.2800
# ...             ...         ...         ...
# 2021-12-27 342.4500    334.6900      7.7600
# 2021-12-28 341.2500    342.4500     -1.2000
# 2021-12-29 341.9500    341.2500      0.7000
# 2021-12-30 339.3200    341.9500     -2.6300
# 2021-12-31 336.3200    339.3200     -3.0000
#
# [2016 rows x 3 columns]

# %%
msft.Price.div(msft.price_lag1) #Relative/Percentage Price Changes
# Out:
# Date
# 2013-12-31      NaN
# 2014-01-02   0.9933
# 2014-01-03   0.9933
# 2014-01-06   0.9789
# 2014-01-07   1.0077
#               ...
# 2021-12-27   1.0232
# 2021-12-28   0.9965
# 2021-12-29   1.0021
# 2021-12-30   0.9923
# 2021-12-31   0.9912
# Length: 2016, dtype: float64

# %%
(36.9100 / 37.1600 - 1) * 100 #2014
# Out:
# -0.6727664155005364
